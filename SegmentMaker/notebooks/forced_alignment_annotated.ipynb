# %% [markdown]
# # Forced Alignment with Wav2Vec2
#
# **Author**: [Moto Hira](moto@meta.com)_
#
# This tutorial shows how to align transcript to speech with
# ``torchaudio``, using CTC segmentation algorithm described in
# [CTC-Segmentation of Large Corpora for German End-to-end Speech
# Recognition](https://arxiv.org/abs/2007.09127)_.

# %%
import torch
import torchaudio

print(torch.__version__)
print(torchaudio.__version__)


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# 1.13.1+cu117
# 0.13.1+cu117
# cuda

# %% [markdown]
# ## Overview
#
# The process of alignment looks like the following.
#
# 1. Estimate the frame-wise label probability from audio waveform
# 2. Generate the trellis matrix which represents the probability of
#    labels aligned at time step.
# 3. Find the most likely path from the trellis matrix.
#
# In this example, we use ``torchaudio``\ ’s ``Wav2Vec2`` model for
# acoustic feature extraction.

# %% [markdown]
# ## Preparation
#
# First we import the necessary packages, and fetch data that we work on.

# %%
# %matplotlib inline

from dataclasses import dataclass

import IPython
import matplotlib
import matplotlib.pyplot as plt

matplotlib.rcParams["figure.figsize"] = [16.0, 4.8]

torch.random.manual_seed(0)

SPEECH_FILE = torchaudio.utils.download_asset("tutorial-assets/Lab41-SRI-VOiCES-src-sp0307-ch127535-sg0042.wav")

# %% [markdown]
# ## Generate frame-wise label probability
#
# The first step is to generate the label class porbability of each aduio
# frame. We can use a Wav2Vec2 model that is trained for ASR. Here we use
# :py:func:`torchaudio.pipelines.WAV2VEC2_ASR_BASE_960H`.
#
# ``torchaudio`` provides easy access to pretrained models with associated
# labels.
#
# <div class="alert alert-info"><h4>Note</h4><p>In the subsequent sections, we will compute the probability in
#    log-domain to avoid numerical instability. For this purpose, we
#    normalize the ``emission`` with :py:func:`torch.log_softmax`.</p></div>

# %%
SPEECH_FILE = '/home/paperspace/repos/transformers/examples/research_projects/wav2vec2/wavs/g2.wav'

# bundle = torchaudio.pipelines.WAV2VEC2_ASR_LARGE_LV60K_960H #WAV2VEC2_ASR_BASE_960H
# model = bundle.get_model().to(device)

def load_model(model_name):
    bundle = getattr(torchaudio.pipelines, model_name)
    model = bundle.get_model()
    return model, bundle

MODEL_SR = 16_000

model_name = 'WAV2VEC2_ASR_LARGE_LV60K_960H'
model, bundle = load_model(model_name)
model.eval()
model.to(device)

def load_audio(wav_file):
    wav, sr = torchaudio.load(wav_file)
    if sr != MODEL_SR:
        print(f'Resampling from {sr} to {MODEL_SR}')
        wav = torchaudio.transforms.Resample(sr, MODEL_SR)(wav)
    return wav

audio = load_audio(SPEECH_FILE)
audio = audio.to(device)

def get_emissions(model, audio):
    emissions, _ = model(audio)
    emissions = torch.log_softmax(emissions, dim=-1)
    return emissions

emissions = get_emissions(model, audio)
emissions = emissions[0].detach().cpu()

# %%
# labels = bundle.get_labels()
# with torch.inference_mode():
#     waveform, _ = torchaudio.load(SPEECH_FILE)
#     emissions, _ = model(waveform.to(device))
#     emissions = torch.log_softmax(emissions, dim=-1)

# emission = emissions[0].cpu().detach()
# Out:
# Downloading: "https://download.pytorch.org/torchaudio/models/wav2vec2_fairseq_large_lv60k_asr_ls960.pth" to /home/paperspace/.cache/torch/hub/checkpoints/wav2vec2_fairseq_large_lv60k_asr_ls960.pth
#   0%|          | 0.00/1.18G [00:00<?, ?B/s]

# %%
# torchaudio.pipelines.WAV2VEC2_ASR_LARGE_LV60K_960H

# %% [markdown]
# ### Visualization

# %%
print(labels)
plt.imshow(emission.T)
plt.colorbar()
plt.title("Frame-wise class probability")
plt.xlabel("Time")
plt.ylabel("Labels")
plt.show()
# Out:
# ('-', '|', 'E', 'T', 'A', 'O', 'N', 'I', 'H', 'S', 'R', 'D', 'L', 'U', 'M', 'W', 'C', 'F', 'G', 'Y', 'P', 'B', 'V', 'K', "'", 'X', 'J', 'Q', 'Z')

# %% [markdown]
# ## Generate alignment probability (trellis)
#
# From the emission matrix, next we generate the trellis which represents
# the probability of transcript labels occur at each time frame.
#
# Trellis is 2D matrix with time axis and label axis. The label axis
# represents the transcript that we are aligning. In the following, we use
# $t$ to denote the index in time axis and $j$ to denote the
# index in label axis. $c_j$ represents the label at label index
# $j$.
#
# To generate, the probability of time step $t+1$, we look at the
# trellis from time step $t$ and emission at time step $t+1$.
# There are two path to reach to time step $t+1$ with label
# $c_{j+1}$. The first one is the case where the label was
# $c_{j+1}$ at $t$ and there was no label change from
# $t$ to $t+1$. The other case is where the label was
# $c_j$ at $t$ and it transitioned to the next label
# $c_{j+1}$ at $t+1$.
#
# The follwoing diagram illustrates this transition.
#
# <img src="https://download.pytorch.org/torchaudio/tutorial-assets/ctc-forward.png">
#
# Since we are looking for the most likely transitions, we take the more
# likely path for the value of $k_{(t+1, j+1)}$, that is
#
# $k_{(t+1, j+1)} = max( k_{(t, j)} p(t+1, c_{j+1}), k_{(t, j+1)} p(t+1, repeat) )$
#
# where $k$ represents is trellis matrix, and $p(t, c_j)$
# represents the probability of label $c_j$ at time step $t$.
# $repeat$ represents the blank token from CTC formulation. (For the
# detail of CTC algorithm, please refer to the *Sequence Modeling with CTC*
# [[distill.pub](https://distill.pub/2017/ctc/)_])

# %%
# transcript = "I|HAD|THAT|CURIOSITY|BESIDE|ME|AT|THIS|MOMENT"
ts = 'four score and seven years ago our fathers brought forth on this continent a new nation conceived in Liberty and dedicated to the proposition that all men are created equal'
ts = '|'.join(ts.split(' ')).upper()
transcript = ts

# %%
dictionary = {c: i for i, c in enumerate(labels)}

tokens = [dictionary[c] for c in transcript]
print(list(zip(transcript, tokens)))
# Out:
# [('F', 17), ('O', 5), ('U', 13), ('R', 10), ('|', 1), ('S', 9), ('C', 16), ('O', 5), ('R', 10), ('E', 2), ('|', 1), ('A', 4), ('N', 6), ('D', 11), ('|', 1), ('S', 9), ('E', 2), ('V', 22), ('E', 2), ('N', 6), ('|', 1), ('Y', 19), ('E', 2), ('A', 4), ('R', 10), ('S', 9), ('|', 1), ('A', 4), ('G', 18), ('O', 5), ('|', 1), ('O', 5), ('U', 13), ('R', 10), ('|', 1), ('F', 17), ('A', 4), ('T', 3), ('H', 8), ('E', 2), ('R', 10), ('S', 9), ('|', 1), ('B', 21), ('R', 10), ('O', 5), ('U', 13), ('G', 18), ('H', 8), ('T', 3), ('|', 1), ('F', 17), ('O', 5), ('R', 10), ('T', 3), ('H', 8), ('|', 1), ('O', 5), ('N', 6), ('|', 1), ('T', 3), ('H', 8), ('I', 7), ('S', 9), ('|', 1), ('C', 16), ('O', 5), ('N', 6), ('T', 3), ('I', 7), ('N', 6), ('E', 2), ('N', 6), ('T', 3), ('|', 1), ('A', 4), ('|', 1), ('N', 6), ('E', 2), ('W', 15), ('|', 1), ('N', 6), ('A', 4), ('T', 3), ('I', 7), ('O', 5), ('N', 6), ('|', 1), ('C', 16), ('O', 5), ('N', 6), ('C', 16), ('E', 2), ('I', 7), ('V', 22), ('E', 2), ('D', 11), ('|', 1), ('I', 7), ('N', 6), ('|', 1), ('L', 12), ('I', 7), ('B', 21), ('E', 2), ('R', 10), ('T', 3), ('Y', 19), ('|', 1), ('A', 4), ('N', 6), ('D', 11), ('|', 1), ('D', 11), ('E', 2), ('D', 11), ('I', 7), ('C', 16), ('A', 4), ('T', 3), ('E', 2), ('D', 11), ('|', 1), ('T', 3), ('O', 5), ('|', 1), ('T', 3), ('H', 8), ('E', 2), ('|', 1), ('P', 20), ('R', 10), ('O', 5), ('P', 20), ('O', 5), ('S', 9), ('I', 7), ('T', 3), ('I', 7), ('O', 5), ('N', 6), ('|', 1), ('T', 3), ('H', 8), ('A', 4), ('T', 3), ('|', 1), ('A', 4), ('L', 12), ('L', 12), ('|', 1), ('M', 14), ('E', 2), ('N', 6), ('|', 1), ('A', 4), ('R', 10), ('E', 2), ('|', 1), ('C', 16), ('R', 10), ('E', 2), ('A', 4), ('T', 3), ('E', 2), ('D', 11), ('|', 1), ('E', 2), ('Q', 27), ('U', 13), ('A', 4), ('L', 12)]

# %%
def get_trellis(emission, tokens, blank_id=0):
    num_frame = emission.size(0)
    num_tokens = len(tokens)

    # Trellis has extra diemsions for both time axis and tokens.
    # The extra dim for tokens represents <SoS> (start-of-sentence)
    # The extra dim for time axis is for simplification of the code.
    trellis = torch.empty((num_frame + 1, num_tokens + 1))
    trellis[0, 0] = 0
    trellis[1:, 0] = torch.cumsum(emission[:, 0], 0)
    trellis[0, -num_tokens:] = -float("inf")
    trellis[-num_tokens:, 0] = float("inf")

    for t in range(num_frame):
        trellis[t + 1, 1:] = torch.maximum(
            # Score for staying at the same token
            trellis[t, 1:] + emission[t, blank_id],
            # Score for changing to the next token
            trellis[t, :-1] + emission[t, tokens],
        )
    return trellis


trellis = get_trellis(emission, tokens)

# %% [markdown]
# ### Visualization

# %%
plt.imshow(trellis[1:, 1:].T, origin="lower")
plt.annotate("- Inf", (trellis.size(1) / 5, trellis.size(1) / 1.5))
plt.colorbar()
plt.show()

# %% [markdown]
# In the above visualization, we can see that there is a trace of high
# probability crossing the matrix diagonally.

# %% [markdown]
# ## Find the most likely path (backtracking)
#
# Once the trellis is generated, we will traverse it following the
# elements with high probability.
#
# We will start from the last label index with the time step of highest
# probability, then, we traverse back in time, picking stay
# ($c_j \rightarrow c_j$) or transition
# ($c_j \rightarrow c_{j+1}$), based on the post-transition
# probability $k_{t, j} p(t+1, c_{j+1})$ or
# $k_{t, j+1} p(t+1, repeat)$.
#
# Transition is done once the label reaches the beginning.
#
# The trellis matrix is used for path-finding, but for the final
# probability of each segment, we take the frame-wise probability from
# emission matrix.

# %%
@dataclass
class Point:
    token_index: int
    time_index: int
    score: float


def backtrack(trellis, emission, tokens, blank_id=0):
    # Note:
    # j and t are indices for trellis, which has extra dimensions
    # for time and tokens at the beginning.
    # When referring to time frame index `T` in trellis,
    # the corresponding index in emission is `T-1`.
    # Similarly, when referring to token index `J` in trellis,
    # the corresponding index in transcript is `J-1`.
    j = trellis.size(1) - 1
    t_start = torch.argmax(trellis[:, j]).item()

    path = []
    for t in range(t_start, 0, -1):
        # 1. Figure out if the current position was stay or change
        # Note (again):
        # `emission[J-1]` is the emission at time frame `J` of trellis dimension.
        # Score for token staying the same from time frame J-1 to T.
        stayed = trellis[t - 1, j] + emission[t - 1, blank_id]
        # Score for token changing from C-1 at T-1 to J at T.
        changed = trellis[t - 1, j - 1] + emission[t - 1, tokens[j - 1]]

        # 2. Store the path with frame-wise probability.
        prob = emission[t - 1, tokens[j - 1] if changed > stayed else 0].exp().item()
        # Return token index and time index in non-trellis coordinate.
        path.append(Point(j - 1, t - 1, prob))

        # 3. Update the token
        if changed > stayed:
            j -= 1
            if j == 0:
                break
    else:
        raise ValueError("Failed to align")
    return path[::-1]


path = backtrack(trellis, emission, tokens)
for p in path:
    print(p)
# Out:
# Point(token_index=0, time_index=20, score=0.999729335308075)
# Point(token_index=0, time_index=21, score=0.9998425245285034)
# Point(token_index=0, time_index=22, score=0.9998425245285034)
# Point(token_index=0, time_index=23, score=0.9998968839645386)
# Point(token_index=0, time_index=24, score=0.9999039173126221)
# Point(token_index=0, time_index=25, score=0.9999120235443115)
# Point(token_index=0, time_index=26, score=0.9998944997787476)
# Point(token_index=1, time_index=27, score=0.9998621940612793)
# Point(token_index=2, time_index=28, score=0.9940004348754883)
# Point(token_index=2, time_index=29, score=0.9930425882339478)
# Point(token_index=3, time_index=30, score=0.9997875094413757)
# Point(token_index=3, time_index=31, score=0.33480027318000793)
# Point(token_index=3, time_index=32, score=0.9929527640342712)
# Point(token_index=3, time_index=33, score=0.18757317960262299)
# Point(token_index=4, time_index=34, score=0.8319892287254333)
# Point(token_index=4, time_index=35, score=0.9997966885566711)
# Point(token_index=4, time_index=36, score=0.999869704246521)
# Point(token_index=5, time_index=37, score=0.999991774559021)
# Point(token_index=5, time_index=38, score=0.9998949766159058)
# Point(token_index=5, time_index=39, score=0.9999048709869385)
# Point(token_index=5, time_index=40, score=0.9999040365219116)
# Point(token_index=6, time_index=41, score=0.9999562501907349)
# Point(token_index=6, time_index=42, score=0.9998990297317505)
# Point(token_index=6, time_index=43, score=0.9999010562896729)
# Point(token_index=6, time_index=44, score=0.9999097585678101)
# Point(token_index=6, time_index=45, score=0.9999746084213257)
# Point(token_index=6, time_index=46, score=0.9999061822891235)
# Point(token_index=6, time_index=47, score=0.999908447265625)
# Point(token_index=6, time_index=48, score=0.9999092817306519)
# Point(token_index=7, time_index=49, score=0.9999403953552246)
# Point(token_index=7, time_index=50, score=0.9998873472213745)
# Point(token_index=8, time_index=51, score=0.9999549388885498)
# Point(token_index=8, time_index=52, score=0.9998947381973267)
# Point(token_index=9, time_index=53, score=0.9999216794967651)
# Point(token_index=9, time_index=54, score=0.9998632669448853)
# Point(token_index=10, time_index=55, score=0.9996411800384521)
# Point(token_index=10, time_index=56, score=0.999833345413208)
# Point(token_index=10, time_index=57, score=0.9998931884765625)
# Point(token_index=11, time_index=58, score=0.9969191551208496)
# Point(token_index=12, time_index=59, score=0.9988180994987488)
# Point(token_index=13, time_index=60, score=0.9494404196739197)
# Point(token_index=13, time_index=61, score=0.09314429014921188)
# Point(token_index=14, time_index=62, score=0.9997602105140686)
# Point(token_index=14, time_index=63, score=0.9998947381973267)
# Point(token_index=15, time_index=64, score=0.9997367262840271)
# Point(token_index=15, time_index=65, score=0.9998979568481445)
# Point(token_index=15, time_index=66, score=0.9998999834060669)
# Point(token_index=15, time_index=67, score=0.9999063014984131)
# Point(token_index=16, time_index=68, score=0.9999603033065796)
# Point(token_index=16, time_index=69, score=0.9998883008956909)
# Point(token_index=16, time_index=70, score=0.9999110698699951)
# Point(token_index=17, time_index=71, score=0.9999271631240845)
# Point(token_index=17, time_index=72, score=0.9999043941497803)
# Point(token_index=18, time_index=73, score=0.9998979568481445)
# Point(token_index=18, time_index=74, score=0.8683549165725708)
# Point(token_index=19, time_index=75, score=0.9995786547660828)
# Point(token_index=19, time_index=76, score=0.7251853942871094)
# Point(token_index=20, time_index=77, score=0.9994617104530334)
# Point(token_index=21, time_index=78, score=0.9998937845230103)
# Point(token_index=22, time_index=79, score=0.9990407824516296)
# Point(token_index=22, time_index=80, score=0.0010325597831979394)
# Point(token_index=23, time_index=81, score=0.9999785423278809)
# Point(token_index=23, time_index=82, score=0.6606800556182861)
# Point(token_index=24, time_index=83, score=0.9999724626541138)
# Point(token_index=24, time_index=84, score=0.9998648166656494)
# Point(token_index=24, time_index=85, score=0.9998542070388794)
# Point(token_index=25, time_index=86, score=0.9999172687530518)
# Point(token_index=25, time_index=87, score=0.9998382329940796)
# Point(token_index=26, time_index=88, score=0.9998428821563721)
# Point(token_index=26, time_index=89, score=0.9998869895935059)
# Point(token_index=27, time_index=90, score=0.9999165534973145)
# Point(token_index=27, time_index=91, score=0.9998726844787598)
# Point(token_index=27, time_index=92, score=0.9998908042907715)
# Point(token_index=28, time_index=93, score=0.9999672174453735)
# Point(token_index=28, time_index=94, score=0.9999011754989624)
# Point(token_index=28, time_index=95, score=0.9999017715454102)
# Point(token_index=28, time_index=96, score=0.9998975992202759)
# Point(token_index=29, time_index=97, score=0.9999252557754517)
# Point(token_index=29, time_index=98, score=0.9998633861541748)
# Point(token_index=29, time_index=99, score=0.9998680353164673)
# Point(token_index=30, time_index=100, score=0.9999008178710938)
# Point(token_index=30, time_index=101, score=0.013831422664225101)
# Point(token_index=30, time_index=102, score=0.9998934268951416)
# Point(token_index=30, time_index=103, score=0.9999871253967285)
# Point(token_index=30, time_index=104, score=0.999953031539917)
# Point(token_index=30, time_index=105, score=0.9998897314071655)
# Point(token_index=30, time_index=106, score=0.9999986886978149)
# Point(token_index=30, time_index=107, score=0.9998966455459595)
# Point(token_index=30, time_index=108, score=0.999997615814209)
# Point(token_index=30, time_index=109, score=0.9999957084655762)
# Point(token_index=30, time_index=110, score=0.999883770942688)
# Point(token_index=30, time_index=111, score=0.9999970197677612)
# Point(token_index=30, time_index=112, score=0.9998817443847656)
# Point(token_index=30, time_index=113, score=0.9999785423278809)
# Point(token_index=30, time_index=114, score=0.9998878240585327)
# Point(token_index=30, time_index=115, score=0.9998911619186401)
# Point(token_index=30, time_index=116, score=0.999887228012085)
# Point(token_index=30, time_index=117, score=0.9998847246170044)
# Point(token_index=30, time_index=118, score=0.9998681545257568)
# Point(token_index=30, time_index=119, score=0.9998805522918701)
# Point(token_index=30, time_index=120, score=0.9998704195022583)
# Point(token_index=30, time_index=121, score=0.9998862743377686)
# Point(token_index=30, time_index=122, score=0.9998884201049805)
# Point(token_index=30, time_index=123, score=0.9998807907104492)
# Point(token_index=31, time_index=124, score=0.9994377493858337)
# Point(token_index=32, time_index=125, score=0.9988265633583069)
# Point(token_index=32, time_index=126, score=0.9998793601989746)
# Point(token_index=33, time_index=127, score=0.999927282333374)
# Point(token_index=33, time_index=128, score=0.7548825144767761)
# Point(token_index=34, time_index=129, score=0.9999269247055054)
# Point(token_index=34, time_index=130, score=0.999819815158844)
# Point(token_index=34, time_index=131, score=0.9998898506164551)
# Point(token_index=35, time_index=132, score=0.9999035596847534)
# Point(token_index=35, time_index=133, score=0.9998965263366699)
# Point(token_index=35, time_index=134, score=0.9999045133590698)
# Point(token_index=35, time_index=135, score=0.9999088048934937)
# Point(token_index=35, time_index=136, score=0.9999080896377563)
# Point(token_index=35, time_index=137, score=0.9998966455459595)
# Point(token_index=36, time_index=138, score=0.9998027682304382)
# Point(token_index=36, time_index=139, score=0.9997997879981995)
# Point(token_index=36, time_index=140, score=0.9998292922973633)
# Point(token_index=36, time_index=141, score=0.9998805522918701)
# Point(token_index=37, time_index=142, score=0.9998785257339478)
# Point(token_index=38, time_index=143, score=0.9999208450317383)
# Point(token_index=38, time_index=144, score=0.9999074935913086)
# Point(token_index=39, time_index=145, score=0.9999699592590332)
# Point(token_index=39, time_index=146, score=0.9998520612716675)
# Point(token_index=40, time_index=147, score=0.9999595880508423)
# Point(token_index=40, time_index=148, score=0.9998382329940796)
# Point(token_index=40, time_index=149, score=0.972068727016449)
# Point(token_index=41, time_index=150, score=0.9999620914459229)
# Point(token_index=41, time_index=151, score=0.03229794651269913)
# Point(token_index=42, time_index=152, score=0.999896764755249)
# Point(token_index=42, time_index=153, score=0.999882698059082)
# Point(token_index=42, time_index=154, score=0.9998853206634521)
# Point(token_index=42, time_index=155, score=0.9998904466629028)
# Point(token_index=43, time_index=156, score=0.9996862411499023)
# Point(token_index=43, time_index=157, score=0.9998748302459717)
# Point(token_index=44, time_index=158, score=0.9980389475822449)
# Point(token_index=44, time_index=159, score=0.9999103546142578)
# Point(token_index=45, time_index=160, score=0.9998748302459717)
# Point(token_index=46, time_index=161, score=0.9993446469306946)
# Point(token_index=46, time_index=162, score=0.6893634796142578)
# Point(token_index=47, time_index=163, score=0.9992802739143372)
# Point(token_index=48, time_index=164, score=0.9992056488990784)
# Point(token_index=49, time_index=165, score=0.9994751811027527)
# Point(token_index=49, time_index=166, score=0.4999650716781616)
# Point(token_index=49, time_index=167, score=0.07309410721063614)
# Point(token_index=50, time_index=168, score=0.9996185302734375)
# Point(token_index=50, time_index=169, score=0.9998737573623657)
# Point(token_index=51, time_index=170, score=0.9997414946556091)
# Point(token_index=51, time_index=171, score=0.9998862743377686)
# Point(token_index=51, time_index=172, score=0.9998916387557983)
# Point(token_index=51, time_index=173, score=0.9999046325683594)
# Point(token_index=51, time_index=174, score=0.1470690667629242)
# Point(token_index=52, time_index=175, score=0.9999462366104126)
# Point(token_index=52, time_index=176, score=0.06074691563844681)
# Point(token_index=53, time_index=177, score=0.9999399185180664)
# Point(token_index=53, time_index=178, score=0.9998633861541748)
# Point(token_index=53, time_index=179, score=0.9998358488082886)
# Point(token_index=54, time_index=180, score=0.9996166229248047)
# Point(token_index=55, time_index=181, score=0.99960857629776)
# Point(token_index=55, time_index=182, score=0.9582356810569763)
# Point(token_index=56, time_index=183, score=0.9988909363746643)
# Point(token_index=56, time_index=184, score=0.13721995055675507)
# Point(token_index=56, time_index=185, score=0.9993057250976562)
# Point(token_index=57, time_index=186, score=0.9948784112930298)
# Point(token_index=58, time_index=187, score=0.9991903901100159)
# Point(token_index=58, time_index=188, score=0.9341648817062378)
# Point(token_index=59, time_index=189, score=0.9997273087501526)
# Point(token_index=59, time_index=190, score=0.999805748462677)
# Point(token_index=60, time_index=191, score=0.9967008233070374)
# Point(token_index=61, time_index=192, score=0.9990822076797485)
# Point(token_index=62, time_index=193, score=0.9997765421867371)
# Point(token_index=62, time_index=194, score=0.9998706579208374)
# Point(token_index=62, time_index=195, score=0.07983217388391495)
# Point(token_index=63, time_index=196, score=0.9990948438644409)
# Point(token_index=63, time_index=197, score=0.13286852836608887)
# Point(token_index=64, time_index=198, score=0.9998007416725159)
# Point(token_index=64, time_index=199, score=0.9998828172683716)
# Point(token_index=65, time_index=200, score=0.9997460246086121)
# Point(token_index=65, time_index=201, score=0.999896764755249)
# Point(token_index=65, time_index=202, score=0.999900221824646)
# Point(token_index=65, time_index=203, score=0.9999055862426758)
# Point(token_index=65, time_index=204, score=0.9999101161956787)
# Point(token_index=66, time_index=205, score=0.9997962117195129)
# Point(token_index=66, time_index=206, score=0.9960958361625671)
# Point(token_index=67, time_index=207, score=0.9997681975364685)
# Point(token_index=67, time_index=208, score=0.9998902082443237)
# Point(token_index=68, time_index=209, score=0.99980229139328)
# Point(token_index=68, time_index=210, score=0.985471248626709)
# Point(token_index=68, time_index=211, score=0.08981449156999588)
# Point(token_index=68, time_index=212, score=0.9998940229415894)
# Point(token_index=69, time_index=213, score=0.9998971223831177)
# Point(token_index=69, time_index=214, score=0.9998979568481445)
# Point(token_index=70, time_index=215, score=0.9993578791618347)
# Point(token_index=70, time_index=216, score=0.9999040365219116)
# Point(token_index=70, time_index=217, score=0.9998995065689087)
# Point(token_index=71, time_index=218, score=0.999592125415802)
# Point(token_index=72, time_index=219, score=0.9999455213546753)
# Point(token_index=72, time_index=220, score=0.9998893737792969)
# Point(token_index=72, time_index=221, score=0.1998203992843628)
# Point(token_index=73, time_index=222, score=0.9988885521888733)
# Point(token_index=74, time_index=223, score=0.9997512698173523)
# Point(token_index=74, time_index=224, score=0.9998296499252319)
# Point(token_index=74, time_index=225, score=0.999873161315918)
# Point(token_index=74, time_index=226, score=0.9998736381530762)
# Point(token_index=74, time_index=227, score=0.9998824596405029)
# Point(token_index=74, time_index=228, score=0.9998836517333984)
# Point(token_index=74, time_index=229, score=0.9998663663864136)
# Point(token_index=74, time_index=230, score=0.9998539686203003)
# Point(token_index=74, time_index=231, score=0.9998785257339478)
# Point(token_index=75, time_index=232, score=0.9994508624076843)
# Point(token_index=75, time_index=233, score=0.08753695338964462)
# Point(token_index=76, time_index=234, score=0.995101273059845)
# Point(token_index=76, time_index=235, score=0.9998592138290405)
# Point(token_index=76, time_index=236, score=0.9998631477355957)
# Point(token_index=77, time_index=237, score=0.9999120235443115)
# Point(token_index=77, time_index=238, score=0.9999022483825684)
# Point(token_index=78, time_index=239, score=0.9997987151145935)
# Point(token_index=79, time_index=240, score=0.9999116659164429)
# Point(token_index=79, time_index=241, score=0.9976092576980591)
# Point(token_index=79, time_index=242, score=0.011265459470450878)
# Point(token_index=80, time_index=243, score=0.9995392560958862)
# Point(token_index=80, time_index=244, score=0.9998863935470581)
# Point(token_index=81, time_index=245, score=0.9998815059661865)
# Point(token_index=81, time_index=246, score=0.9999099969863892)
# Point(token_index=81, time_index=247, score=0.9999107122421265)
# Point(token_index=81, time_index=248, score=0.9999140501022339)
# Point(token_index=82, time_index=249, score=0.9999606609344482)
# Point(token_index=82, time_index=250, score=0.999890923500061)
# Point(token_index=82, time_index=251, score=0.9999001026153564)
# Point(token_index=82, time_index=252, score=0.9998959302902222)
# Point(token_index=83, time_index=253, score=0.9999679327011108)
# Point(token_index=83, time_index=254, score=0.9998760223388672)
# Point(token_index=84, time_index=255, score=0.9999436140060425)
# Point(token_index=84, time_index=256, score=0.9999170303344727)
# Point(token_index=85, time_index=257, score=0.999962329864502)
# Point(token_index=86, time_index=258, score=0.9999555349349976)
# Point(token_index=86, time_index=259, score=0.9998698234558105)
# Point(token_index=87, time_index=260, score=0.9998354911804199)
# Point(token_index=87, time_index=261, score=0.9998736381530762)
# Point(token_index=87, time_index=262, score=0.9998905658721924)
# Point(token_index=87, time_index=263, score=0.9999974966049194)
# Point(token_index=87, time_index=264, score=0.9999983310699463)
# Point(token_index=87, time_index=265, score=0.9998819828033447)
# Point(token_index=87, time_index=266, score=0.9999980926513672)
# Point(token_index=87, time_index=267, score=0.9999045133590698)
# Point(token_index=87, time_index=268, score=0.9998890161514282)
# Point(token_index=87, time_index=269, score=0.9999978542327881)
# Point(token_index=87, time_index=270, score=0.9999924898147583)
# Point(token_index=87, time_index=271, score=0.9999988079071045)
# Point(token_index=87, time_index=272, score=0.9999973773956299)
# Point(token_index=87, time_index=273, score=0.9998810291290283)
# Point(token_index=87, time_index=274, score=0.9999949932098389)
# Point(token_index=87, time_index=275, score=0.9998898506164551)
# Point(token_index=87, time_index=276, score=0.9998912811279297)
# Point(token_index=87, time_index=277, score=0.9999948740005493)
# Point(token_index=87, time_index=278, score=0.9998873472213745)
# Point(token_index=87, time_index=279, score=0.9998821020126343)
# Point(token_index=87, time_index=280, score=0.9998819828033447)
# Point(token_index=87, time_index=281, score=0.9998893737792969)
# Point(token_index=87, time_index=282, score=0.999890923500061)
# Point(token_index=88, time_index=283, score=0.9998989105224609)
# Point(token_index=88, time_index=284, score=0.9999161958694458)
# Point(token_index=88, time_index=285, score=0.9999186992645264)
# Point(token_index=89, time_index=286, score=0.9999734163284302)
# Point(token_index=90, time_index=287, score=0.9999654293060303)
# Point(token_index=90, time_index=288, score=0.9999058246612549)
# Point(token_index=90, time_index=289, score=0.99989914894104)
# Point(token_index=90, time_index=290, score=0.9999005794525146)
# Point(token_index=91, time_index=291, score=0.9999362230300903)
# Point(token_index=91, time_index=292, score=0.9999041557312012)
# Point(token_index=91, time_index=293, score=0.9999024868011475)
# Point(token_index=91, time_index=294, score=0.9999018907546997)
# Point(token_index=91, time_index=295, score=0.9998965263366699)
# Point(token_index=92, time_index=296, score=0.9999687671661377)
# Point(token_index=93, time_index=297, score=0.9998970031738281)
# Point(token_index=93, time_index=298, score=0.0021943077445030212)
# Point(token_index=94, time_index=299, score=0.9999613761901855)
# Point(token_index=94, time_index=300, score=0.9999003410339355)
# Point(token_index=95, time_index=301, score=0.9997921586036682)
# Point(token_index=96, time_index=302, score=0.9996635913848877)
# Point(token_index=96, time_index=303, score=0.2745717465877533)
# Point(token_index=97, time_index=304, score=0.9997357726097107)
# Point(token_index=97, time_index=305, score=0.6580002307891846)
# Point(token_index=98, time_index=306, score=0.9948850274085999)
# Point(token_index=99, time_index=307, score=0.9994829893112183)
# Point(token_index=99, time_index=308, score=0.19551868736743927)
# Point(token_index=100, time_index=309, score=0.9998111128807068)
# Point(token_index=101, time_index=310, score=0.9999722242355347)
# Point(token_index=101, time_index=311, score=0.99989914894104)
# Point(token_index=102, time_index=312, score=0.9999678134918213)
# Point(token_index=102, time_index=313, score=0.9998841285705566)
# Point(token_index=102, time_index=314, score=0.9998946189880371)
# Point(token_index=103, time_index=315, score=0.9997045397758484)
# Point(token_index=104, time_index=316, score=0.9999856948852539)
# Point(token_index=104, time_index=317, score=0.9998499155044556)
# Point(token_index=105, time_index=318, score=0.999962568283081)
# Point(token_index=105, time_index=319, score=0.9998953342437744)
# Point(token_index=106, time_index=320, score=0.9998980760574341)
# Point(token_index=106, time_index=321, score=0.999873161315918)
# Point(token_index=106, time_index=322, score=0.9998812675476074)
# Point(token_index=106, time_index=323, score=0.8395947813987732)
# Point(token_index=107, time_index=324, score=0.9996999502182007)
# Point(token_index=108, time_index=325, score=0.9996814727783203)
# Point(token_index=108, time_index=326, score=0.9998207688331604)
# Point(token_index=108, time_index=327, score=0.9998956918716431)
# Point(token_index=108, time_index=328, score=0.9999690055847168)
# Point(token_index=108, time_index=329, score=0.999997615814209)
# Point(token_index=108, time_index=330, score=0.9998804330825806)
# Point(token_index=108, time_index=331, score=0.9999959468841553)
# Point(token_index=108, time_index=332, score=0.9998865127563477)
# Point(token_index=108, time_index=333, score=0.9998964071273804)
# Point(token_index=108, time_index=334, score=0.9998648166656494)
# Point(token_index=108, time_index=335, score=0.9998855590820312)
# Point(token_index=109, time_index=336, score=0.999796450138092)
# Point(token_index=110, time_index=337, score=0.9997542500495911)
# Point(token_index=110, time_index=338, score=0.9998825788497925)
# Point(token_index=111, time_index=339, score=0.999705970287323)
# Point(token_index=112, time_index=340, score=0.999840497970581)
# Point(token_index=112, time_index=341, score=0.21989989280700684)
# Point(token_index=113, time_index=342, score=0.9999641180038452)
# Point(token_index=113, time_index=343, score=0.9999058246612549)
# Point(token_index=113, time_index=344, score=0.9999051094055176)
# Point(token_index=114, time_index=345, score=0.9999926090240479)
# Point(token_index=114, time_index=346, score=0.9999024868011475)
# Point(token_index=114, time_index=347, score=0.999897837638855)
# Point(token_index=114, time_index=348, score=0.9998968839645386)
# Point(token_index=115, time_index=349, score=0.9999703168869019)
# Point(token_index=115, time_index=350, score=0.9998947381973267)
# Point(token_index=116, time_index=351, score=0.999982476234436)
# Point(token_index=116, time_index=352, score=0.999900221824646)
# Point(token_index=116, time_index=353, score=0.9998966455459595)
# Point(token_index=117, time_index=354, score=0.999915599822998)
# Point(token_index=117, time_index=355, score=0.999850869178772)
# Point(token_index=117, time_index=356, score=0.9999001026153564)
# Point(token_index=118, time_index=357, score=0.9998451471328735)
# Point(token_index=118, time_index=358, score=0.9998981952667236)
# Point(token_index=118, time_index=359, score=0.9998980760574341)
# Point(token_index=119, time_index=360, score=0.9998151659965515)
# Point(token_index=119, time_index=361, score=0.9998931884765625)
# Point(token_index=120, time_index=362, score=0.9996060729026794)
# Point(token_index=121, time_index=363, score=0.9996594190597534)
# Point(token_index=121, time_index=364, score=0.9998483657836914)
# Point(token_index=122, time_index=365, score=0.9998879432678223)
# Point(token_index=122, time_index=366, score=0.07286587357521057)
# Point(token_index=123, time_index=367, score=0.9995911717414856)
# Point(token_index=124, time_index=368, score=0.9997734427452087)
# Point(token_index=124, time_index=369, score=0.9998563528060913)
# Point(token_index=125, time_index=370, score=0.9997736811637878)
# Point(token_index=126, time_index=371, score=0.9999330043792725)
# Point(token_index=127, time_index=372, score=0.9999122619628906)
# Point(token_index=128, time_index=373, score=0.9995554089546204)
# Point(token_index=128, time_index=374, score=0.4178871810436249)
# Point(token_index=129, time_index=375, score=0.9999364614486694)
# Point(token_index=129, time_index=376, score=0.9998794794082642)
# Point(token_index=130, time_index=377, score=0.9999532699584961)
# Point(token_index=131, time_index=378, score=0.9986608028411865)
# Point(token_index=131, time_index=379, score=0.001339214388281107)
# Point(token_index=131, time_index=380, score=0.9999134540557861)
# Point(token_index=132, time_index=381, score=0.9999464750289917)
# Point(token_index=132, time_index=382, score=0.999880313873291)
# Point(token_index=132, time_index=383, score=0.999872088432312)
# Point(token_index=132, time_index=384, score=0.9998923540115356)
# Point(token_index=133, time_index=385, score=0.9999542236328125)
# Point(token_index=133, time_index=386, score=0.9998940229415894)
# Point(token_index=133, time_index=387, score=0.9999091625213623)
# Point(token_index=134, time_index=388, score=0.9999808073043823)
# Point(token_index=134, time_index=389, score=0.999891996383667)
# Point(token_index=134, time_index=390, score=0.7560833096504211)
# Point(token_index=135, time_index=391, score=0.999345600605011)
# Point(token_index=135, time_index=392, score=0.9999057054519653)
# Point(token_index=135, time_index=393, score=0.9999053478240967)
# Point(token_index=136, time_index=394, score=0.9999680519104004)
# Point(token_index=136, time_index=395, score=0.9998892545700073)
# Point(token_index=136, time_index=396, score=0.9999001026153564)
# Point(token_index=137, time_index=397, score=0.9999308586120605)
# Point(token_index=137, time_index=398, score=0.999902606010437)
# Point(token_index=138, time_index=399, score=0.9999648332595825)
# Point(token_index=138, time_index=400, score=0.999911904335022)
# Point(token_index=139, time_index=401, score=0.9998170733451843)
# Point(token_index=140, time_index=402, score=0.9998962879180908)
# Point(token_index=140, time_index=403, score=0.9998283386230469)
# Point(token_index=140, time_index=404, score=0.0042086634784936905)
# Point(token_index=141, time_index=405, score=0.9997726082801819)
# Point(token_index=141, time_index=406, score=0.9998787641525269)
# Point(token_index=141, time_index=407, score=0.9998831748962402)
# Point(token_index=142, time_index=408, score=0.9998195767402649)
# Point(token_index=143, time_index=409, score=0.9999305009841919)
# Point(token_index=143, time_index=410, score=0.9999016523361206)
# Point(token_index=144, time_index=411, score=0.9997630715370178)
# Point(token_index=145, time_index=412, score=0.9995531439781189)
# Point(token_index=145, time_index=413, score=0.7670096755027771)
# Point(token_index=146, time_index=414, score=0.999901533126831)
# Point(token_index=146, time_index=415, score=0.9998737573623657)
# Point(token_index=146, time_index=416, score=0.9998825788497925)
# Point(token_index=146, time_index=417, score=0.9998800754547119)
# Point(token_index=146, time_index=418, score=0.9998947381973267)
# Point(token_index=146, time_index=419, score=0.9999088048934937)
# Point(token_index=147, time_index=420, score=0.9999209642410278)
# Point(token_index=148, time_index=421, score=0.9999039173126221)
# Point(token_index=148, time_index=422, score=0.9999018907546997)
# Point(token_index=148, time_index=423, score=0.9999121427536011)
# Point(token_index=148, time_index=424, score=0.9998520612716675)
# Point(token_index=149, time_index=425, score=0.9999256134033203)
# Point(token_index=150, time_index=426, score=0.9998732805252075)
# Point(token_index=150, time_index=427, score=0.22444742918014526)
# Point(token_index=150, time_index=428, score=0.9998928308486938)
# Point(token_index=151, time_index=429, score=0.9997945427894592)
# Point(token_index=151, time_index=430, score=0.999902606010437)
# Point(token_index=151, time_index=431, score=0.9999362230300903)
# Point(token_index=151, time_index=432, score=0.9999359846115112)
# Point(token_index=151, time_index=433, score=0.9999080896377563)
# Point(token_index=151, time_index=434, score=0.9998910427093506)
# Point(token_index=152, time_index=435, score=0.9983838796615601)
# Point(token_index=153, time_index=436, score=0.9997699856758118)
# Point(token_index=153, time_index=437, score=0.9998451471328735)
# Point(token_index=153, time_index=438, score=0.024037517607212067)
# Point(token_index=154, time_index=439, score=0.9993769526481628)
# Point(token_index=154, time_index=440, score=0.9998648166656494)
# Point(token_index=154, time_index=441, score=0.9998682737350464)
# Point(token_index=154, time_index=442, score=0.9998663663864136)
# Point(token_index=154, time_index=443, score=0.9998807907104492)
# Point(token_index=154, time_index=444, score=0.9998829364776611)
# Point(token_index=154, time_index=445, score=0.9998507499694824)
# Point(token_index=154, time_index=446, score=0.9998537302017212)
# Point(token_index=155, time_index=447, score=0.9979727864265442)
# Point(token_index=155, time_index=448, score=0.9998538494110107)
# Point(token_index=156, time_index=449, score=0.9998120665550232)
# Point(token_index=157, time_index=450, score=0.9994969367980957)
# Point(token_index=157, time_index=451, score=0.013417373411357403)
# Point(token_index=158, time_index=452, score=0.9967343807220459)
# Point(token_index=159, time_index=453, score=0.9999637603759766)
# Point(token_index=159, time_index=454, score=0.9998722076416016)
# Point(token_index=159, time_index=455, score=0.9999139308929443)
# Point(token_index=159, time_index=456, score=0.09977196902036667)
# Point(token_index=160, time_index=457, score=0.9999788999557495)
# Point(token_index=160, time_index=458, score=0.9999160766601562)
# Point(token_index=161, time_index=459, score=0.9999603033065796)
# Point(token_index=161, time_index=460, score=0.9998859167098999)
# Point(token_index=161, time_index=461, score=0.9998098015785217)
# Point(token_index=161, time_index=462, score=0.9998984336853027)
# Point(token_index=162, time_index=463, score=0.9999054670333862)
# Point(token_index=162, time_index=464, score=0.9998897314071655)
# Point(token_index=162, time_index=465, score=0.9999006986618042)
# Point(token_index=163, time_index=466, score=0.9998041987419128)
# Point(token_index=163, time_index=467, score=0.9998741149902344)
# Point(token_index=163, time_index=468, score=0.9998887777328491)
# Point(token_index=164, time_index=469, score=0.9995890259742737)
# Point(token_index=165, time_index=470, score=0.999672532081604)
# Point(token_index=165, time_index=471, score=0.9998268485069275)
# Point(token_index=166, time_index=472, score=0.9994649291038513)
# Point(token_index=166, time_index=473, score=0.0024867053143680096)
# Point(token_index=166, time_index=474, score=0.9998526573181152)
# Point(token_index=166, time_index=475, score=0.9998626708984375)
# Point(token_index=166, time_index=476, score=0.9998636245727539)
# Point(token_index=166, time_index=477, score=0.9998762607574463)
# Point(token_index=166, time_index=478, score=0.9998669624328613)
# Point(token_index=166, time_index=479, score=0.9998754262924194)
# Point(token_index=166, time_index=480, score=0.9998917579650879)
# Point(token_index=167, time_index=481, score=0.999967098236084)
# Point(token_index=167, time_index=482, score=0.9998431205749512)
# Point(token_index=167, time_index=483, score=0.9998883008956909)
# Point(token_index=168, time_index=484, score=0.9999748468399048)
# Point(token_index=168, time_index=485, score=0.9998775720596313)
# Point(token_index=168, time_index=486, score=0.9998742341995239)
# Point(token_index=169, time_index=487, score=0.9999922513961792)
# Point(token_index=169, time_index=488, score=0.9998762607574463)
# Point(token_index=169, time_index=489, score=0.9999078512191772)
# Point(token_index=170, time_index=490, score=0.999931812286377)
# Point(token_index=171, time_index=491, score=0.9998486042022705)

# %% [markdown]
# ### Visualization

# %%
def plot_trellis_with_path(trellis, path):
    # To plot trellis with path, we take advantage of 'nan' value
    trellis_with_path = trellis.clone()
    for _, p in enumerate(path):
        trellis_with_path[p.time_index, p.token_index] = float("nan")
    plt.imshow(trellis_with_path[1:, 1:].T, origin="lower")


plot_trellis_with_path(trellis, path)
plt.title("The path found by backtracking")
plt.show()

# %% [markdown]
# Looking good. Now this path contains repetations for the same labels, so
# let’s merge them to make it close to the original transcript.
#
# When merging the multiple path points, we simply take the average
# probability for the merged segments.

# %%
# Merge the labels
@dataclass
class Segment:
    label: str
    start: int
    end: int
    score: float

    def __repr__(self):
        return f"{self.label}\t({self.score:4.2f}): [{self.start:5d}, {self.end:5d})"

    @property
    def length(self):
        return self.end - self.start


def merge_repeats(path):
    i1, i2 = 0, 0
    segments = []
    while i1 < len(path):
        while i2 < len(path) and path[i1].token_index == path[i2].token_index:
            i2 += 1
        score = sum(path[k].score for k in range(i1, i2)) / (i2 - i1)
        segments.append(
            Segment(
                transcript[path[i1].token_index],
                path[i1].time_index,
                path[i2 - 1].time_index + 1,
                score,
            )
        )
        i1 = i2
    return segments


segments = merge_repeats(path)
for seg in segments:
    print(seg)
# Out:
# F	(1.00): [   20,    27)
# O	(1.00): [   27,    28)
# U	(0.99): [   28,    30)
# R	(0.63): [   30,    34)
# |	(0.94): [   34,    37)
# S	(1.00): [   37,    41)
# C	(1.00): [   41,    49)
# O	(1.00): [   49,    51)
# R	(1.00): [   51,    53)
# E	(1.00): [   53,    55)
# |	(1.00): [   55,    58)
# A	(1.00): [   58,    59)
# N	(1.00): [   59,    60)
# D	(0.52): [   60,    62)
# |	(1.00): [   62,    64)
# S	(1.00): [   64,    68)
# E	(1.00): [   68,    71)
# V	(1.00): [   71,    73)
# E	(0.93): [   73,    75)
# N	(0.86): [   75,    77)
# |	(1.00): [   77,    78)
# Y	(1.00): [   78,    79)
# E	(0.50): [   79,    81)
# A	(0.83): [   81,    83)
# R	(1.00): [   83,    86)
# S	(1.00): [   86,    88)
# |	(1.00): [   88,    90)
# A	(1.00): [   90,    93)
# G	(1.00): [   93,    97)
# O	(1.00): [   97,   100)
# |	(0.96): [  100,   124)
# O	(1.00): [  124,   125)
# U	(1.00): [  125,   127)
# R	(0.88): [  127,   129)
# |	(1.00): [  129,   132)
# F	(1.00): [  132,   138)
# A	(1.00): [  138,   142)
# T	(1.00): [  142,   143)
# H	(1.00): [  143,   145)
# E	(1.00): [  145,   147)
# R	(0.99): [  147,   150)
# S	(0.52): [  150,   152)
# |	(1.00): [  152,   156)
# B	(1.00): [  156,   158)
# R	(1.00): [  158,   160)
# O	(1.00): [  160,   161)
# U	(0.84): [  161,   163)
# G	(1.00): [  163,   164)
# H	(1.00): [  164,   165)
# T	(0.52): [  165,   168)
# |	(1.00): [  168,   170)
# F	(0.83): [  170,   175)
# O	(0.53): [  175,   177)
# R	(1.00): [  177,   180)
# T	(1.00): [  180,   181)
# H	(0.98): [  181,   183)
# |	(0.71): [  183,   186)
# O	(0.99): [  186,   187)
# N	(0.97): [  187,   189)
# |	(1.00): [  189,   191)
# T	(1.00): [  191,   192)
# H	(1.00): [  192,   193)
# I	(0.69): [  193,   196)
# S	(0.57): [  196,   198)
# |	(1.00): [  198,   200)
# C	(1.00): [  200,   205)
# O	(1.00): [  205,   207)
# N	(1.00): [  207,   209)
# T	(0.77): [  209,   213)
# I	(1.00): [  213,   215)
# N	(1.00): [  215,   218)
# E	(1.00): [  218,   219)
# N	(0.73): [  219,   222)
# T	(1.00): [  222,   223)
# |	(1.00): [  223,   232)
# A	(0.54): [  232,   234)
# |	(1.00): [  234,   237)
# N	(1.00): [  237,   239)
# E	(1.00): [  239,   240)
# W	(0.67): [  240,   243)
# |	(1.00): [  243,   245)
# N	(1.00): [  245,   249)
# A	(1.00): [  249,   253)
# T	(1.00): [  253,   255)
# I	(1.00): [  255,   257)
# O	(1.00): [  257,   258)
# N	(1.00): [  258,   260)
# |	(1.00): [  260,   283)
# C	(1.00): [  283,   286)
# O	(1.00): [  286,   287)
# N	(1.00): [  287,   291)
# C	(1.00): [  291,   296)
# E	(1.00): [  296,   297)
# I	(0.50): [  297,   299)
# V	(1.00): [  299,   301)
# E	(1.00): [  301,   302)
# D	(0.64): [  302,   304)
# |	(0.83): [  304,   306)
# I	(0.99): [  306,   307)
# N	(0.60): [  307,   309)
# |	(1.00): [  309,   310)
# L	(1.00): [  310,   312)
# I	(1.00): [  312,   315)
# B	(1.00): [  315,   316)
# E	(1.00): [  316,   318)
# R	(1.00): [  318,   320)
# T	(0.96): [  320,   324)
# Y	(1.00): [  324,   325)
# |	(1.00): [  325,   336)
# A	(1.00): [  336,   337)
# N	(1.00): [  337,   339)
# D	(1.00): [  339,   340)
# |	(0.61): [  340,   342)
# D	(1.00): [  342,   345)
# E	(1.00): [  345,   349)
# D	(1.00): [  349,   351)
# I	(1.00): [  351,   354)
# C	(1.00): [  354,   357)
# A	(1.00): [  357,   360)
# T	(1.00): [  360,   362)
# E	(1.00): [  362,   363)
# D	(1.00): [  363,   365)
# |	(0.54): [  365,   367)
# T	(1.00): [  367,   368)
# O	(1.00): [  368,   370)
# |	(1.00): [  370,   371)
# T	(1.00): [  371,   372)
# H	(1.00): [  372,   373)
# E	(0.71): [  373,   375)
# |	(1.00): [  375,   377)
# P	(1.00): [  377,   378)
# R	(0.67): [  378,   381)
# O	(1.00): [  381,   385)
# P	(1.00): [  385,   388)
# O	(0.92): [  388,   391)
# S	(1.00): [  391,   394)
# I	(1.00): [  394,   397)
# T	(1.00): [  397,   399)
# I	(1.00): [  399,   401)
# O	(1.00): [  401,   402)
# N	(0.67): [  402,   405)
# |	(1.00): [  405,   408)
# T	(1.00): [  408,   409)
# H	(1.00): [  409,   411)
# A	(1.00): [  411,   412)
# T	(0.88): [  412,   414)
# |	(1.00): [  414,   420)
# A	(1.00): [  420,   421)
# L	(1.00): [  421,   425)
# L	(1.00): [  425,   426)
# |	(0.74): [  426,   429)
# M	(1.00): [  429,   435)
# E	(1.00): [  435,   436)
# N	(0.67): [  436,   439)
# |	(1.00): [  439,   447)
# A	(1.00): [  447,   449)
# R	(1.00): [  449,   450)
# E	(0.51): [  450,   452)
# |	(1.00): [  452,   453)
# C	(0.77): [  453,   457)
# R	(1.00): [  457,   459)
# E	(1.00): [  459,   463)
# A	(1.00): [  463,   466)
# T	(1.00): [  466,   469)
# E	(1.00): [  469,   470)
# D	(1.00): [  470,   472)
# |	(0.89): [  472,   481)
# E	(1.00): [  481,   484)
# Q	(1.00): [  484,   487)
# U	(1.00): [  487,   490)
# A	(1.00): [  490,   491)
# L	(1.00): [  491,   492)

# %% [markdown]
# ### Visualization

# %%
def plot_trellis_with_segments(trellis, segments, transcript):
    # To plot trellis with path, we take advantage of 'nan' value
    trellis_with_path = trellis.clone()
    for i, seg in enumerate(segments):
        if seg.label != "|":
            trellis_with_path[seg.start + 1 : seg.end + 1, i + 1] = float("nan")

    fig, [ax1, ax2] = plt.subplots(2, 1, figsize=(16, 9.5))
    ax1.set_title("Path, label and probability for each label")
    ax1.imshow(trellis_with_path.T, origin="lower")
    ax1.set_xticks([])

    for i, seg in enumerate(segments):
        if seg.label != "|":
            ax1.annotate(seg.label, (seg.start + 0.7, i + 0.3), weight="bold")
            ax1.annotate(f"{seg.score:.2f}", (seg.start - 0.3, i + 4.3))

    ax2.set_title("Label probability with and without repetation")
    xs, hs, ws = [], [], []
    for seg in segments:
        if seg.label != "|":
            xs.append((seg.end + seg.start) / 2 + 0.4)
            hs.append(seg.score)
            ws.append(seg.end - seg.start)
            ax2.annotate(seg.label, (seg.start + 0.8, -0.07), weight="bold")
    ax2.bar(xs, hs, width=ws, color="gray", alpha=0.5, edgecolor="black")

    xs, hs = [], []
    for p in path:
        label = transcript[p.token_index]
        if label != "|":
            xs.append(p.time_index + 1)
            hs.append(p.score)

    ax2.bar(xs, hs, width=0.5, alpha=0.5)
    ax2.axhline(0, color="black")
    ax2.set_xlim(ax1.get_xlim())
    ax2.set_ylim(-0.1, 1.1)


plot_trellis_with_segments(trellis, segments, transcript)
plt.tight_layout()
plt.show()

# %% [markdown]
# Looks good. Now let’s merge the words. The Wav2Vec2 model uses ``'|'``
# as the word boundary, so we merge the segments before each occurance of
# ``'|'``.
#
# Then, finally, we segment the original audio into segmented audio and
# listen to them to see if the segmentation is correct.

# %%
# Merge words
def merge_words(segments, separator="|"):
    words = []
    i1, i2 = 0, 0
    while i1 < len(segments):
        if i2 >= len(segments) or segments[i2].label == separator:
            if i1 != i2:
                segs = segments[i1:i2]
                word = "".join([seg.label for seg in segs])
                score = sum(seg.score * seg.length for seg in segs) / sum(seg.length for seg in segs)
                words.append(Segment(word, segments[i1].start, segments[i2 - 1].end, score))
            i1 = i2 + 1
            i2 = i1
        else:
            i2 += 1
    return words


word_segments = merge_words(segments)
for word in word_segments:
    print(word)
# Out:
# FOUR	(0.89): [   20,    34)
# SCORE	(1.00): [   37,    55)
# AND	(0.76): [   58,    62)
# SEVEN	(0.97): [   64,    77)
# YEARS	(0.87): [   78,    88)
# AGO	(1.00): [   90,   100)
# OUR	(0.95): [  124,   129)
# FATHERS	(0.95): [  132,   152)
# BROUGHT	(0.85): [  156,   168)
# FORTH	(0.86): [  170,   183)
# ON	(0.98): [  186,   189)
# THIS	(0.74): [  191,   198)
# CONTINENT	(0.92): [  200,   223)
# A	(0.54): [  232,   234)
# NEW	(0.83): [  237,   243)
# NATION	(1.00): [  245,   260)
# CONCEIVED	(0.92): [  283,   304)
# IN	(0.73): [  306,   309)
# LIBERTY	(0.99): [  310,   325)
# AND	(1.00): [  336,   340)
# DEDICATED	(1.00): [  342,   365)
# TO	(1.00): [  367,   370)
# THE	(0.85): [  371,   375)
# PROPOSITION	(0.92): [  377,   405)
# THAT	(0.96): [  408,   414)
# ALL	(1.00): [  420,   426)
# MEN	(0.90): [  429,   439)
# ARE	(0.80): [  447,   452)
# CREATED	(0.95): [  453,   472)
# EQUAL	(1.00): [  481,   492)

# %% [markdown]
# ### Visualization

# %%
def plot_alignments(trellis, segments, word_segments, waveform):
    trellis_with_path = trellis.clone()
    for i, seg in enumerate(segments):
        if seg.label != "|":
            trellis_with_path[seg.start + 1 : seg.end + 1, i + 1] = float("nan")

    fig, [ax1, ax2] = plt.subplots(2, 1, figsize=(16, 9.5))

    ax1.imshow(trellis_with_path[1:, 1:].T, origin="lower")
    ax1.set_xticks([])
    ax1.set_yticks([])

    for word in word_segments:
        ax1.axvline(word.start - 0.5)
        ax1.axvline(word.end - 0.5)

    for i, seg in enumerate(segments):
        if seg.label != "|":
            ax1.annotate(seg.label, (seg.start, i + 0.3))
            ax1.annotate(f"{seg.score:.2f}", (seg.start, i + 4), fontsize=8)

    # The original waveform
    ratio = waveform.size(0) / (trellis.size(0) - 1)
    ax2.plot(waveform)
    for word in word_segments:
        x0 = ratio * word.start
        x1 = ratio * word.end
        ax2.axvspan(x0, x1, alpha=0.1, color="red")
        ax2.annotate(f"{word.score:.2f}", (x0, 0.8))

    for seg in segments:
        if seg.label != "|":
            ax2.annotate(seg.label, (seg.start * ratio, 0.9))
    xticks = ax2.get_xticks()
    plt.xticks(xticks, xticks / bundle.sample_rate)
    ax2.set_xlabel("time [second]")
    ax2.set_yticks([])
    ax2.set_ylim(-1.0, 1.0)
    ax2.set_xlim(0, waveform.size(-1))


plot_alignments(
    trellis,
    segments,
    word_segments,
    waveform[0],
)
plt.show()

# %%
# A trick to embed the resulting audio to the generated file.
# `IPython.display.Audio` has to be the last call in a cell,
# and there should be only one call par cell.
def display_segment(i):
    ratio = waveform.size(1) / (trellis.size(0) - 1)
    word = word_segments[i]
    x0 = int(ratio * word.start)
    x1 = int(ratio * word.end)
    print(f"{word.label} ({word.score:.2f}): {x0 / bundle.sample_rate:.3f} - {x1 / bundle.sample_rate:.3f} sec")
    segment = waveform[:, x0:x1]
    return IPython.display.Audio(segment.numpy(), rate=bundle.sample_rate)

# %%
# Generate the audio for each segment
print(transcript)
IPython.display.Audio(SPEECH_FILE)
# Out:
# FOUR|SCORE|AND|SEVEN|YEARS|AGO|OUR|FATHERS|BROUGHT|FORTH|ON|THIS|CONTINENT|A|NEW|NATION|CONCEIVED|IN|LIBERTY|AND|DEDICATED|TO|THE|PROPOSITION|THAT|ALL|MEN|ARE|CREATED|EQUAL
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display_segment(0)
# Out:
# FOUR (0.89): 0.400 - 0.680 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display_segment(1)
# Out:
# SCORE (1.00): 0.741 - 1.101 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display_segment(2)
# Out:
# AND (0.76): 1.161 - 1.241 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display_segment(3)
# Out:
# SEVEN (0.97): 1.281 - 1.541 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display_segment(4)
# Out:
# YEARS (0.87): 1.561 - 1.761 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display_segment(5)
# Out:
# AGO (1.00): 1.801 - 2.002 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display_segment(6)
# Out:
# OUR (0.95): 2.482 - 2.582 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display_segment(7)
# Out:
# FATHERS (0.95): 2.642 - 3.042 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display_segment(8)
# Out:
# BROUGHT (0.85): 3.122 - 3.363 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display_segment(-1)
# Out:
# EQUAL (1.00): 9.628 - 9.848 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Conclusion
#
# In this tutorial, we looked how to use torchaudio’s Wav2Vec2 model to
# perform CTC segmentation for forced alignment.
